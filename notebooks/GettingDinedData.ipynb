# %%
import json
import pandas as pd

# %% [markdown]
# # User story: Getting data easly from Dyned web api
# As a researcher I would like to be able to build a dataframe sample from the 1D dined database given the available studies and measurements so that I can easily perform different analysis with data analysis tools.
#
# ## Acceptance criteria
# - Given a list of measurements and studies associated with this measurements.
# - When calling dined method or command,
# - Then a new dataFrame with all the measurements is generated
# (The api documentation could have simple images explaining the measurements....)

# %% [markdown]
# The package could provide a kind of ORM that allows me to build a data frame from selecting a study.

# %%
import dined.data_1D as data

# %% [markdown]
# We get a list of measures to pick, ideally in a dataframe

# %%
measures = json.loads(data.issue_request('GET', 'measures/').content)
measures
# Out:
# [{'id': 1,
#   'name': 'Reach height, standing',
#   'description': '',
#   'measure_id': 1,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 2,
#   'name': 'Stature',
#   'description': 'The vertical distance from the floor to the top of the head (vertex).',
#   'measure_id': 2,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': 'https://www.youtube.com/watch?v=SvSEX6rFHZc',
#   'is_locked': False},
#  {'id': 3,
#   'name': 'Eye height, standing',
#   'description': 'Vertical distance between the standing surface and the inner corner of the right eye.',
#   'measure_id': 3,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 4,
#   'name': 'Shoulder height',
#   'description': 'Vertical distance from the standing surface to the acromion.',
#   'measure_id': 4,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 5,
#   'name': 'Elbow height, standing',
#   'description': 'Vertical distance from the floor to the lowest bony point of the elbow.',
#   'measure_id': 5,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 6,
#   'name': 'Fist height, standing',
#   'description': 'The vertical distance from the floor to the middle of the grip device in the fist.',
#   'measure_id': 6,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': 'https://www.youtube.com/watch?v=_11UUrQQzgQ',
#   'is_locked': False},
#  {'id': 7,
#   'name': 'Head height',
#   'description': 'The height of the head perpendicular to the Frankfort Plane, from menton to vertex.',
#   'measure_id': 7,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 8,
#   'name': 'Hip height',
#   'description': '',
#   'measure_id': 8,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 9,
#   'name': 'Thigh clearance, sitting',
#   'description': 'Vertical distance from the seat to the highest point on the superior surface of the thigh at the abdominal-thigh junction.',
#   'measure_id': 9,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'thickness',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 10,
#   'name': 'Instep height',
#   'description': 'The vertical distance from the footrest surface to the instep (the junction of the lower (the junction of the lower leg and foot).',
#   'measure_id': 10,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 6,
#   'correlation_type': 'thickness',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 11,
#   'name': 'Chin-crown height',
#   'description': 'The rectilinear distance from chin to crown.',
#   'measure_id': 11,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 12,
#   'name': 'Shoulder-elbow length',
#   'description': 'The maximum vertical distance from the acromion to the lowest bony point of the flexed elbow.',
#   'measure_id': 12,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 13,
#   'name': 'Elbow height, sitting',
#   'description': 'Vertical distance from the sitting surface to the lowest bony point of the elbow with the underarm horizontal. In some datasets this measure is calculated by subtracting shoulder-elbow length from shoulder height.',
#   'measure_id': 13,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 14,
#   'name': 'Popliteal height, sitting',
#   'description': 'The vertical distance from the footrest surface to the hollow of the knee.',
#   'measure_id': 14,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 15,
#   'name': 'Shoulder height, sitting',
#   'description': 'The vertical distance from the seat to the acromion.',
#   'measure_id': 15,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': 'https://www.youtube.com/watch?v=nAnIpufwz_k',
#   'is_locked': True},
#  {'id': 16,
#   'name': 'Eye height, sitting',
#   'description': 'The vertical distance from the seat to the inner corner of the right eye.',
#   'measure_id': 16,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 17,
#   'name': 'Sitting height',
#   'description': 'The vertical distance from the seat to the vertex (top of the head).',
#   'measure_id': 17,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': 'https://www.youtube.com/watch?v=aXQmiJmQxGE',
#   'is_locked': True},
#  {'id': 18,
#   'name': 'Reach height, sitting',
#   'description': 'The vertical distance from the horizontal surface to the mid-point of the grip device.',
#   'measure_id': 18,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 19,
#   'name': 'Reach depth',
#   'description': '',
#   'measure_id': 19,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 20,
#   'name': 'Arm length',
#   'description': 'The horizontal distance from the back of the measuring chair to the most distal point of the grip device.',
#   'measure_id': 20,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 21,
#   'name': 'Breadth over the elbows',
#   'description': 'The maximum horizontal distance between the lateral sides of the elbows.',
#   'measure_id': 21,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 22,
#   'name': 'Shoulder breadth (bi-deltoid)',
#   'description': 'The horizontal breath across the shoulders.',
#   'measure_id': 22,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 23,
#   'name': 'Head breadth',
#   'description': 'Maximum breadth of the head above the ears measured perpendicular to the midsagittal plane.',
#   'measure_id': 23,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 24,
#   'name': 'Hip breadth',
#   'description': 'Maximum breadth across the hips.',
#   'measure_id': 24,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 25,
#   'name': 'Hip breadth, sitting',
#   'description': 'The maximum horizontal distance across the hips, parallel to the seat.',
#   'measure_id': 25,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 26,
#   'name': 'Knee breadth',
#   'description': 'Breath of the right knee at the condyles of the upper leg.',
#   'measure_id': 26,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 27,
#   'name': 'Chest depth',
#   'description': 'The maximum horizontal distance between the front and the back of the trunk at the nipples.',
#   'measure_id': 27,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': 'thickness',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 28,
#   'name': 'Head depth',
#   'description': '',
#   'measure_id': 28,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'thickness',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 29,
#   'name': 'Elbow-finger tip length',
#   'description': 'The maximum horizontal distance between the lowest bony point of the flexed elbow and the tip of the middle finger of the right hand.',
#   'measure_id': 29,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 30,
#   'name': 'Abdominal depth',
#   'description': 'The horizontal distance from the back of the measuring chair to the most distal point of the abdomen.',
#   'measure_id': 30,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'thickness',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 31,
#   'name': 'Elbow-grip length',
#   'description': 'The maximum horizontal distance between the lowest bony point of the flexed elbow and the middle of the grip device.',
#   'measure_id': 31,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 32,
#   'name': 'Buttock-popliteal depth',
#   'description': 'The horizontal distance from the back of the measuring chair to the hollow of the knee parallel of the long axis of the upper leg.',
#   'measure_id': 32,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 33,
#   'name': 'Buttock-knee depth, sitting',
#   'description': 'The horizontal distance from the posterior surface of the right buttock to the anterior surface of the right knee parallel to the long axis of the upper leg.',
#   'measure_id': 33,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 34,
#   'name': 'Buttock foot length, sitting',
#   'description': 'The horizontal distance from the buttock to the sole of the foot of the stretched leg.',
#   'measure_id': 34,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 35,
#   'name': 'Head circumference',
#   'description': 'Maximum about horizontal circumference of the head measured just the glabella and over the opisthocranion.',
#   'measure_id': 35,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 36,
#   'name': 'Neck base circumference',
#   'description': '',
#   'measure_id': 36,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 37,
#   'name': 'Chest circumference',
#   'description': 'Circumference of the chest measured at nipple level.',
#   'measure_id': 37,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 38,
#   'name': 'Waist circumference',
#   'description': 'Circumference of trunk at a level midway between the lowest ribs and upper ilia crest.',
#   'measure_id': 38,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 39,
#   'name': 'Hip circumference',
#   'description': '',
#   'measure_id': 39,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 40,
#   'name': 'Upperarm circumference',
#   'description': 'Maximum circumference of the upper arm perpendicular to the long axis of the body, midway between shoulder and elbow.',
#   'measure_id': 40,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 2,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 41,
#   'name': 'Foot length',
#   'description': 'The maximum horizontal distance from the heel of the longest toe of the right foot unshod, parallel to the long axis of the foot.',
#   'measure_id': 41,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 6,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 42,
#   'name': 'Foot breadth',
#   'description': 'The maximum width across the ball of the right foot unshod.',
#   'measure_id': 42,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 6,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 43,
#   'name': 'Hand length',
#   'description': 'The distance from the wrist crease tot the tip of the middle finger, parallel to the fingers.',
#   'measure_id': 43,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 44,
#   'name': 'Hand width (without thumb)',
#   'description': 'The distance from the radial to ulnar side of the hand, measured at the distal extremities of the metacarpals.',
#   'measure_id': 44,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 45,
#   'name': 'Thumb breadth',
#   'description': 'The maximum distance from the radial to the ulnar side of the thumb at the distal interphalangial joint.',
#   'measure_id': 45,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 46,
#   'name': 'Forefinger breadth',
#   'description': 'The maximum distance from the radial to the ulnair side of the forefinger at the middle of the distal phalanx.',
#   'measure_id': 46,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 47,
#   'name': 'Hand width (with thumb)',
#   'description': '',
#   'measure_id': 47,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 48,
#   'name': 'Hand thickness',
#   'description': 'The maximum distance between the palm and the back of the hand at the middle finger joint.',
#   'measure_id': 48,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'thickness',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 49,
#   'name': 'Pink breadth',
#   'description': 'Maximum distance between the palm and the back of the hand at the middle finger joint.',
#   'measure_id': 49,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 50,
#   'name': 'Middlefinger length',
#   'description': 'Distance from the skin crease at the middle finger to the tip of the middle finger, parallel to the long axis of the middle finger.',
#   'measure_id': 50,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 52,
#   'name': 'Hand diameter',
#   'description': 'Minimum diameter of the hand, when in its smallest configuration.',
#   'measure_id': 52,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 53,
#   'name': 'Length pointing finger',
#   'description': '',
#   'measure_id': 53,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 54,
#   'name': 'Grip circumference',
#   'description': 'The maximum circumference of the circle, made by the thumb and forefinger when enclosing a cone.',
#   'measure_id': 54,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 5,
#   'correlation_type': 'circumference',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 55,
#   'name': 'Ear length',
#   'description': 'The maximum distance from the highest tot the lowest point of the auricle.',
#   'measure_id': 55,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 56,
#   'name': 'Body mass',
#   'description': 'Total mass of the body',
#   'measure_id': 56,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'kg',
#   'distribution': None,
#   'decimals': 1,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 57,
#   'name': 'Maximum gripping force',
#   'description': 'The maximum gripping force of a hand exerted for 3 seconds.',
#   'measure_id': 57,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 8,
#   'correlation_type': None,
#   'unit': 'N',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 58,
#   'name': 'Pushing force with 2 hands',
#   'description': 'Maximum pushing force using both arms and hands together, exerted for 3 seconds.',
#   'measure_id': 58,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 8,
#   'correlation_type': None,
#   'unit': 'N',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 59,
#   'name': 'Pulling force 1 hand',
#   'description': 'Maximum pulling force of one hand, exerted for 3 seconds.',
#   'measure_id': 59,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 8,
#   'correlation_type': None,
#   'unit': 'N',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 60,
#   'name': 'Torque with two hands',
#   'description': 'Maximum static torque of two hands and arms, exerted for 3 seconds.',
#   'measure_id': 60,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 8,
#   'correlation_type': None,
#   'unit': 'Nm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 61,
#   'name': 'Rotation of head towards left',
#   'description': 'Maximum rotation of the head towards the left.',
#   'measure_id': 61,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 62,
#   'name': 'Rotation of head towards right',
#   'description': 'Maximum rotation of the head towards the right.',
#   'measure_id': 62,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 63,
#   'name': 'Rotation of head backwards',
#   'description': 'Maximum backward bending (extension) of the head.',
#   'measure_id': 63,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 64,
#   'name': 'Rotation of head toward chest',
#   'description': 'Maximum forward bending (flexion) of the head.',
#   'measure_id': 64,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 65,
#   'name': 'Bending of head towards right shoulder',
#   'description': 'Maximum sideward bending of the head towards the right.',
#   'measure_id': 65,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 66,
#   'name': 'Bending of head towards left shoulder',
#   'description': 'Maximum sideward bending of the head towards the left.',
#   'measure_id': 66,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 67,
#   'name': 'Pronation',
#   'description': 'Maximum rotation of the wrist inward.',
#   'measure_id': 67,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 68,
#   'name': 'Supination',
#   'description': 'Maximum rotation of the wrist outward.',
#   'measure_id': 68,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 69,
#   'name': 'Extension hand',
#   'description': 'Maximum upward bending of the stretched preferred hand from the wrist.',
#   'measure_id': 69,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 70,
#   'name': 'Flexion hand',
#   'description': 'Maximum downward bending of the stretched preferred hand from the wrist.',
#   'measure_id': 70,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 71,
#   'name': 'Radial deviation',
#   'description': 'Maximum radial abduction of the stretched preferred hand from the wrist.',
#   'measure_id': 71,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 72,
#   'name': 'Ulnar deviation',
#   'description': 'Maximum ulnar abduction of the stretched preferred hand from the wrist.',
#   'measure_id': 72,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 73,
#   'name': 'Forefinger flexion',
#   'description': 'Maximum downward bending of the stretched forefinger of the preferred hand.',
#   'measure_id': 73,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 7,
#   'correlation_type': None,
#   'unit': 'deg',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 74,
#   'name': 'Step-up height',
#   'description': 'Vertical distance covered in one comfortable step upwards.',
#   'measure_id': 74,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 75,
#   'name': 'Cervical (c7) height, sitting',
#   'description': 'The vertical distance from the seat to the 7th cervical vertebra.',
#   'measure_id': 75,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 76,
#   'name': 'Cervical (c7)-backplane depth, sitting',
#   'description': 'The horizontal distance from backplane to the 7th cervical vertebra.',
#   'measure_id': 76,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 77,
#   'name': 'Sacrum-backplane depth, sitting',
#   'description': 'The horizontal distance from backplane to the sacrum. As default, measured 10cm above the seat plane.',
#   'measure_id': 77,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 78,
#   'name': 'Heel height',
#   'description': 'The vertical distance (on the shoe) between the bottom of the heel and the floor of the shoe.',
#   'measure_id': 78,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 79,
#   'name': 'Palm height, standing',
#   'description': 'The vertical distance between the floor and the lowest point of the bent palm. Bent as if looking for support on a table.',
#   'measure_id': 79,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 80,
#   'name': 'Age',
#   'description': 'Date of measurement minus birth date then divided by 365.25. In some datasets the result may be rounded to years.',
#   'measure_id': 80,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'years',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 81,
#   'name': 'Crotch height',
#   'description': 'Vertical distance from the floor to the distal part of the inferior ramus of the pubic bone.',
#   'measure_id': 81,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 1,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': False},
#  {'id': 82,
#   'name': 'Calf circumference',
#   'description': 'Maximum circumference of the calf.',
#   'measure_id': 82,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 2,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 83,
#   'name': 'Thigh circumference',
#   'description': 'Maximum circumference of the thigh.',
#   'measure_id': 83,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 2,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 84,
#   'name': 'Foot circumference',
#   'description': 'Maximum circumference of the heel measured at the ankle (the point where the talus is situated) and crossing the rearmost and lowest point of the heel.',
#   'measure_id': 84,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 6,
#   'correlation_type': None,
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 85,
#   'name': 'Face length',
#   'description': 'The length of the face, from menton to sellion or chin to nasal root.',
#   'measure_id': 85,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 86,
#   'name': 'Body Mass Index (BMI)',
#   'description': 'An index for the relationship between the body mass and height.',
#   'measure_id': 86,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:11+00:00',
#   'updated_at': '2020-04-15T12:19:11+00:00',
#   'measure_group_id': 9,
#   'correlation_type': None,
#   'unit': 'kg/m2',
#   'distribution': None,
#   'decimals': 1,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 87,
#   'name': 'Subscapular height',
#   'description': 'Height of the bottom of the shoulder-blade to seat.',
#   'measure_id': 87,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 88,
#   'name': 'Knee height, sitting',
#   'description': 'The vertical distance from the footrest surface to the top of the knee.',
#   'measure_id': 88,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 3,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 89,
#   'name': 'Face width',
#   'description': 'The width of the face, from left to right zygon.',
#   'measure_id': 89,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 90,
#   'name': 'Face length long',
#   'description': 'The long length of the face, from gnathion to sellion or below chin to nasal root.',
#   'measure_id': 90,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 91,
#   'name': 'Lower face length',
#   'description': 'The length of the lower part of the face, from subnasale to gnathion.',
#   'measure_id': 91,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 92,
#   'name': 'Intercanthal width',
#   'description': 'The width the face, from left to right lateral eye corner.',
#   'measure_id': 92,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 93,
#   'name': 'Nasal root breadth',
#   'description': 'The width of the nasal root, from left to right maxillofrontale.',
#   'measure_id': 93,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 94,
#   'name': 'Nose length',
#   'description': 'The length of the nose, from sellion to subnasale.',
#   'measure_id': 94,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 95,
#   'name': 'Nose bridge length',
#   'description': 'The length of the nasal bridge, from sellion to pronasale.',
#   'measure_id': 95,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 96,
#   'name': 'Nasal tip protrusion',
#   'description': 'The depth of the tip of the nose, from subnasale to pronasale.',
#   'measure_id': 96,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 97,
#   'name': 'Nose width',
#   'description': 'The width of the nose, from left to right alare.',
#   'measure_id': 97,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 98,
#   'name': 'Width of mouth',
#   'description': 'The width of the mouth, from left to right chellion.',
#   'measure_id': 98,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 99,
#   'name': 'Height of chin',
#   'description': 'The height of the chin, from gnathion to supramemtale.',
#   'measure_id': 99,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 100,
#   'name': 'Face length short',
#   'description': 'The shortlength of the face , from sellion to supramemtale.',
#   'measure_id': 100,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 101,
#   'name': 'Sellion promentale length',
#   'description': 'The length of the face, from sellion to promentale.',
#   'measure_id': 101,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'height',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 102,
#   'name': 'Bigonial breadth',
#   'description': 'Distance from left to right gonion.',
#   'measure_id': 102,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 103,
#   'name': 'Bitragion breadth',
#   'description': 'Distance between the left and right tragion.',
#   'measure_id': 103,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 104,
#   'name': 'Nasal root protrusion',
#   'description': 'Distance from the sellion to the line between left and right maxillofrontale.',
#   'measure_id': 104,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': 'mm',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True},
#  {'id': 105,
#   'name': 'Relative Nasal Tip Protrusion',
#   'description': 'A relative measure of nasal tip protrusion measured as the ratio of Nasal Tip Protrusion over Nose Length, in percentage.',
#   'measure_id': 105,
#   'locale_id': 1,
#   'created_at': '2020-04-15T12:19:12+00:00',
#   'updated_at': '2020-04-15T12:19:12+00:00',
#   'measure_group_id': 4,
#   'correlation_type': 'breadth',
#   'unit': '%',
#   'distribution': 'normal',
#   'decimals': 0,
#   'video_url': None,
#   'is_locked': True}]

# %%
ms_df = pd.DataFrame(measures)[['id','name','unit']]
ms_df.head()
# Out:
#    id                    name unit
# 0   1  Reach height, standing   mm
# 1   2                 Stature   mm
# 2   3    Eye height, standing   mm
# 3   4         Shoulder height   mm
# 4   5  Elbow height, standing   mm

# %%
def get_by_kw(measures: pd.DataFrame, keyword: str) -> list:
    '''Returns a list of measure names that contain the keyword'''
    names = measures['name']
    # Gets name by keyword
    # First upper, then lower

    results = [name for name in names if keyword in name or keyword.capitalize() in name]
    if results: return results 
    else: print('No results found for this keyword')

# %%
## TODO: Implement this function with different keywords
# get_by_kw(measures, '')

# %%
# Simple ecept for the keyword
get_by_kw(ms_df, 'xx')
# Out:
# No results found for this keyword

# %%
# Works with capitalized keyword and non-capitalized keyword
stature = get_by_kw(ms_df, 'stature')[0]
stature_capitals = get_by_kw(ms_df, 'Stature')[0]
print(stature)
print(stature_capitals)
# Out:
# Stature
# Stature

# %%
query = get_by_kw(ms_df, 'standing')
query
# Out:
# ['Reach height, standing',
#  'Eye height, standing',
#  'Elbow height, standing',
#  'Fist height, standing',
#  'Palm height, standing']

# %%
elbow_height = get_by_kw(ms_df, 'elbow height')[0]
elbow_height
# Out:
# 'Elbow height, standing'

# %% [markdown]
# Now we know which dimensions we need to get the actual data

# %%
# Get a dataframe of measures and their ids
# API call example data.get_measures()
# !We dont have to return a dataframe, we can just return a list of ids
def pick_measures(measures_pick: list, measures:pd.DataFrame)-> pd.DataFrame:
    '''
    Returns a dataframe of measures with the ids in the list
    '''
    # measures_data = pd.DataFrame(['id','name','unit'])
    measures_data = pd.DataFrame()
    assert isinstance(measures, pd.DataFrame) 
    assert isinstance(measures_pick, list)
    for measure_name in measures_pick:
        if measure_name in measures.values:
            row = measures.loc[measures['name'] == measure_name]
            measures_data = pd.concat([row, measures_data], axis=0)
    return measures_data

# %%
ms_df.loc[ms_df['name'] == 'Stature']
# Out:
#    id     name unit
# 1   2  Stature   mm

# %%
picked = pick_measures([stature, elbow_height], ms_df)
picked
# Out:
#    id                    name unit
# 4   5  Elbow height, standing   mm
# 1   2                 Stature   mm

# %% [markdown]
# ## Now we have our selection of measures we want to get data from
# - We still need to specify the study, this is another function we will define later

# %%
# get caesar study
studies = json.loads(data.issue_request('GET', 'studies/').content)

# %%
for study in studies:
    print(study['name'], study['id'])
# Out:
# Dutch elderly 1
# Dutch students 2
# Dutch elderly 3
# Dutch adults 4
# Dutch children 5
# Dutch adults 6
# Dutch adults 7
# International 8
# Dutch Growth 9
# Chilean children 10
# Dutch students 11
# Chilean workers 12
# CAESAR (USA) 13
# CAESAR (IT) 14
# CAESAR (NL) 15
# Dutch children, 0.5-7.0 years (NL) 16

# %% [markdown]
# ## Watch this to properly do the request
# https://www.youtube.com/watch?v=fmf_y8zpOgA&t=637s

# %%
import requests 
import re

URL = 'https://dined.io.tudelft.nl/en/auth/login?return-to=/en'

session = requests.session()

front = session.get(URL)
csrf_token = re.findall(r'<input type="hidden" name="_token" value="(.*)"', front.text)[0]

cookies = session.cookies

payload = {
    'email': 'j.c.urrallanusa@tudelft.nl',
    'password': 'munari86',
    '_token': csrf_token,
}

r = requests.post(URL + '/auth/login', data=payload, cookies=cookies)

print(r.status_code)
# Out:
# 200

# %%
token = r.headers['Set-Cookie']
token
# Out:
# 'XSRF-TOKEN=; expires=Wed, 23-Mar-2022 18:22:09 GMT; Max-Age=7200; path=/, laravel_session=; expires=Wed, 23-Mar-2022 18:22:09 GMT; Max-Age=7200; path=/; httponly'

# %%
ceasar = data.issue_request('GET', 'measurements?study=15&measure=5')

# %%
## Given that I got the measurements from the Dined website, 
# I want to get the data into a format that can be used for analysis.
def get_oned_data(study_id, measure_id)-> pd.DataFrame:
    '''
    Returns a data frame with a sample of antrhopometric data
    '''
    # issue request to get data
    res = data.issue_request('GET', f'measurements?study={study_id}&measure={measure_id}').content
    res = json.loads(res)
    if res is [] or res is None:
        raise ValueError('No data returned')
    else:
        return res

# %%
res = get_oned_data(2,5)
res
# Out:
# []
